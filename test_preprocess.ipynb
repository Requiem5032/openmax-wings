# %%
import os
import matplotlib.pyplot as plt

from utils.data_loader_utils import load_image, make_square

# %%
data_path = 'data/wings-2024'

# %%
img = load_image(os.path.join(data_path, 'Ae_vexans', 'Ae vex 1.tif'))
plt.imshow(img)

# %%
y0 = int(0.2*img.shape[0])
y1 = int(0.8*img.shape[0])

# %%
img = img[y0:y1, :]
plt.imshow(img)

# %%
img = make_square(img)
plt.imshow(img)
